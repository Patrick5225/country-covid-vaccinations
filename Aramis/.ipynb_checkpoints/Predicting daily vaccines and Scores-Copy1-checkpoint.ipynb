# %%
! pip install --user lazypredict
# Out:
# Requirement already satisfied: lazypredict in /Users/patrick/.local/lib/python3.7/site-packages (0.2.9)
# Requirement already satisfied: joblib==1.0.0 in /Users/patrick/.local/lib/python3.7/site-packages (from lazypredict) (1.0.0)
# Requirement already satisfied: tqdm==4.56.0 in /Users/patrick/.local/lib/python3.7/site-packages (from lazypredict) (4.56.0)
# Requirement already satisfied: xgboost==1.1.1 in /Users/patrick/.local/lib/python3.7/site-packages (from lazypredict) (1.1.1)
# Requirement already satisfied: scikit-learn==0.23.1 in /Users/patrick/.local/lib/python3.7/site-packages (from lazypredict) (0.23.1)
# Requirement already satisfied: pytest==5.4.3 in /Users/patrick/.local/lib/python3.7/site-packages (from lazypredict) (5.4.3)
# Requirement already satisfied: six==1.15.0 in /Users/patrick/.local/lib/python3.7/site-packages (from lazypredict) (1.15.0)
# Requirement already satisfied: scipy==1.5.4 in /Users/patrick/.local/lib/python3.7/site-packages (from lazypredict) (1.5.4)
# Requirement already satisfied: numpy==1.19.1 in /Users/patrick/.local/lib/python3.7/site-packages (from lazypredict) (1.19.1)
# Requirement already satisfied: pandas==1.0.5 in /Users/patrick/.local/lib/python3.7/site-packages (from lazypredict) (1.0.5)
# Requirement already satisfied: PyYAML==5.3.1 in /Users/patrick/.local/lib/python3.7/site-packages (from lazypredict) (5.3.1)
# Requirement already satisfied: click==7.1.2 in /Users/patrick/.local/lib/python3.7/site-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: lightgbm==2.3.1 in /Users/patrick/.local/lib/python3.7/site-packages (from lazypredict) (2.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from scikit-learn==0.23.1->lazypredict) (2.1.0)
# Requirement already satisfied: importlib-metadata>=0.12; python_version < "3.8" in /opt/anaconda3/lib/python3.7/site-packages (from pytest==5.4.3->lazypredict) (1.5.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.7/site-packages (from pytest==5.4.3->lazypredict) (0.1.8)
# Requirement already satisfied: more-itertools>=4.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from pytest==5.4.3->lazypredict) (8.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/lib/python3.7/site-packages (from pytest==5.4.3->lazypredict) (19.3.0)
# Requirement already satisfied: py>=1.5.0 in /opt/anaconda3/lib/python3.7/site-packages (from pytest==5.4.3->lazypredict) (1.8.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.7/site-packages (from pytest==5.4.3->lazypredict) (20.1)
# Requirement already satisfied: pluggy<1.0,>=0.12 in /opt/anaconda3/lib/python3.7/site-packages (from pytest==5.4.3->lazypredict) (0.13.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.7/site-packages (from pandas==1.0.5->lazypredict) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda3/lib/python3.7/site-packages (from pandas==1.0.5->lazypredict) (2.8.1)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata>=0.12; python_version < "3.8"->pytest==5.4.3->lazypredict) (2.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/anaconda3/lib/python3.7/site-packages (from packaging->pytest==5.4.3->lazypredict) (2.4.6)

# %%
import pandas as pd
import numpy as np
import sklearn
import time

from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyRegressor


pd.options.mode.chained_assignment = None  # default='warn'
pd.options.display.float_format = '{:,.4f}'.format
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-42-020333a34ec6> in <module>
#       5
#       6 from sklearn.model_selection import train_test_split
# ----> 7 from lazypredict.Supervised import LazyRegressor
#       8
#       9
#
# ~/.local/lib/python3.7/site-packages/lazypredict/Supervised.py in <module>
#      14 from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
#      15 from sklearn.compose import ColumnTransformer
# ---> 16 from sklearn.utils.testing import all_estimators
#      17 from sklearn.base import RegressorMixin
#      18 from sklearn.base import ClassifierMixin
#
# ModuleNotFoundError: No module named 'sklearn.utils.testing'

# %% [markdown]
# ### Reading the inicial data

# %%
df=pd.read_csv("Client_country_info.csv",sep=',')
#inicial dataframe with data from the countries included in the Client Data

dfB=pd.read_csv("Projection_Table.csv",sep=',')
#dataframe that has the estimated daily vaccination per population for each country in the Client Data

# %%
df
# Out:
#            location      continent  total_cases  total_cases_per_million  \
# 0           Albania         Europe     115442.0                40114.671
# 1           Algeria         Africa     114851.0                 2619.117
# 2           Andorra         Europe      11130.0               144049.699
# 3          Anguilla  North America          NaN                      NaN
# 4         Argentina  South America    2177898.0                48188.086
# ..              ...            ...          ...                      ...
# 116  United Kingdom         Europe    4254714.0                62674.392
# 117   United States  North America   29286134.0                88477.039
# 118         Uruguay  South America      67717.0                19494.048
# 119       Venezuela  South America     144277.0                 5073.755
# 120        Zimbabwe         Africa      36377.0                 2447.499
#
#      people_vaccinated  total_vaccinations_per_hundred  \
# 0               6073.0                            0.75
# 1                  NaN                            0.17
# 2               3650.0                            6.36
# 3               3929.0                           26.19
# 4            1564555.0                            4.25
# ..                 ...                             ...
# 116         23053716.0                           35.95
# 117         64071674.0                           29.36
# 118           170134.0                            4.90
# 119            12194.0                            0.04
# 120            36019.0                            0.24
#
#      people_fully_vaccinated_per_hundred  stringency_index  population  \
# 0                                   0.02             89.81     2877800
# 1                                    NaN             92.13    43851043
# 2                                   1.64             59.26       77265
# 3                                    NaN               NaN       15002
# 4                                   0.78            100.00    45195777
# ..                                   ...               ...         ...
# 116                                 1.99             87.96    67886004
# 117                                10.13             75.46   331002647
# 118                                  NaN             72.22     3473727
# 119                                  NaN             90.74    28435943
# 120                                  NaN             87.96    14862927
#
#      population_density  ...  extreme_poverty  cardiovasc_death_rate  \
# 0               104.871  ...              1.1                304.195
# 1                17.348  ...              0.5                278.364
# 2               163.755  ...              NaN                109.135
# 3                   NaN  ...              NaN                    NaN
# 4                16.177  ...              0.6                191.032
# ..                  ...  ...              ...                    ...
# 116             272.898  ...              0.2                122.137
# 117              35.608  ...              1.2                151.089
# 118              19.751  ...              0.1                160.708
# 119              36.253  ...              NaN                204.850
# 120              42.729  ...             21.4                307.846
#
#      diabetes_prevalence  female_smokers  male_smokers  \
# 0                  10.08             7.1          51.2
# 1                   6.73             0.7          30.4
# 2                   7.97            29.0          37.8
# 3                    NaN             NaN           NaN
# 4                   5.50            16.2          27.7
# ..                   ...             ...           ...
# 116                 4.28            20.0          24.7
# 117                10.79            19.1          24.6
# 118                 6.93            14.0          19.9
# 119                 6.47             NaN           NaN
# 120                 1.82             1.6          30.7
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                       NaN                        2.89            78.57
# 1                    83.741                        1.90            76.88
# 2                       NaN                         NaN            83.73
# 3                       NaN                         NaN            81.88
# 4                       NaN                        5.00            76.67
# ..                      ...                         ...              ...
# 116                     NaN                        2.54            81.32
# 117                     NaN                        2.77            78.86
# 118                     NaN                        2.80            77.91
# 119                     NaN                        0.80            72.06
# 120                  36.791                        1.70            61.49
#
#        HDI      distance
# 0    0.795  9.146807e+06
# 1    0.748  8.769593e+06
# 2    0.868  7.844923e+06
# 3    0.865  3.808635e+06
# 4    0.845  9.017652e+06
# ..     ...           ...
# 116  0.932  6.830410e+06
# 117  0.926  0.000000e+00
# 118  0.817  8.780559e+06
# 119  0.711  4.507978e+06
# 120  0.571  1.433032e+07
#
# [121 rows x 24 columns]

# %%
dfB
# Out:
#             country  population    daily_rate  num_datapoints        R2  \
# 0           Albania     2877800  6.417286e+02              20  0.612512
# 1           Algeria    43851043  3.750000e+04               3  0.750300
# 2           Andorra       77265  3.360000e+02               7  0.982911
# 3          Anguilla       15002  1.320800e+03               4  0.998495
# 4         Argentina    45195777  2.263269e+04              48  0.940498
# ..              ...         ...           ...             ...       ...
# 116  United Kingdom    67886004  3.920764e+05              59  0.998178
# 117   United States   331002647  1.430394e+06              63  0.985730
# 118         Uruguay     3473727  1.447369e+04               6  0.973251
# 119       Venezuela    28435943  6.097000e+03               3  0.759655
# 120        Zimbabwe    14862927  2.695958e+03              14  0.990605
#
#      daily_rate_pop
# 0          0.000223
# 1          0.000855
# 2          0.004349
# 3          0.088042
# 4          0.000501
# ..              ...
# 116        0.005776
# 117        0.004321
# 118        0.004167
# 119        0.000214
# 120        0.000181
#
# [121 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['location', 'continent', 'total_cases', 'total_cases_per_million',
#        'people_vaccinated', 'total_vaccinations_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'stringency_index', 'population',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'HDI', 'distance'],
#       dtype='object')

# %% [markdown]
# ### Selecting a model

# %% [markdown]
# #### Here we run the lazypredict library in search of a model that better suits our case

# %%
X1=df[['population','gdp_per_capita','HDI']] # selecting the variables to apply in the model
Y1=dfB['daily_rate_pop'] #target variable

# %%
X_train1, X_test1, Y_train1, Y_test1 =train_test_split(X1,Y1,test_size=.3,random_state =2) 
regr=LazyRegressor(verbose=0,predictions=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-c23af6831ca4> in <module>
#       1 X_train1, X_test1, Y_train1, Y_test1 =train_test_split(X1,Y1,test_size=.3,random_state =2)
# ----> 2 regr=LazyRegressor(verbose=0,predictions=True)
#
# NameError: name 'LazyRegressor' is not defined

# %%
start_time_2=time.time()
models_r,predictions_r=regr.fit(X_train1, X_test1, Y_train1, Y_test1)
end_time_2=time.time()
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:01<00:00, 38.86it/s]

# %%
models_r
# Out:
#                                R-Squared   RMSE  Time Taken
# Model
# HistGradientBoostingRegressor     0.0793 0.0406      0.1316
# LGBMRegressor                     0.0682 0.0409      0.0668
# RandomForestRegressor             0.0514 0.0412      0.1167
# KNeighborsRegressor               0.0458 0.0414      0.0140
# AdaBoostRegressor                 0.0405 0.0415      0.0429
# BaggingRegressor                  0.0362 0.0416      0.0219
# ExtraTreesRegressor               0.0298 0.0417      0.0838
# ExtraTreeRegressor                0.0233 0.0418      0.0100
# XGBRegressor                      0.0203 0.0419      0.0668
# GradientBoostingRegressor         0.0131 0.0421      0.0309
# LinearRegression                  0.0038 0.0423      0.0100
# TransformedTargetRegressor        0.0038 0.0423      0.0100
# Lars                              0.0038 0.0423      0.0110
# Ridge                             0.0036 0.0423      0.0090
# RidgeCV                           0.0020 0.0423      0.0120
# LassoCV                           0.0000 0.0423      0.0608
# ElasticNetCV                      0.0000 0.0423      0.0528
# BayesianRidge                    -0.0001 0.0423      0.0090
# LassoLarsIC                      -0.0005 0.0423      0.0150
# OrthogonalMatchingPursuit        -0.0047 0.0424      0.0100
# OrthogonalMatchingPursuitCV      -0.0047 0.0424      0.0130
# DecisionTreeRegressor            -0.0050 0.0424      0.0090
# TweedieRegressor                 -0.0080 0.0425      0.0109
# SGDRegressor                     -0.0096 0.0425      0.0099
# LassoLarsCV                      -0.0125 0.0426      0.0229
# LarsCV                           -0.0125 0.0426      0.0180
# GammaRegressor                   -0.0132 0.0426      0.0090
# NuSVR                            -0.0140 0.0426      0.0140
# PoissonRegressor                 -0.0325 0.0430      0.0100
# ElasticNet                       -0.0329 0.0430      0.0080
# Lasso                            -0.0329 0.0430      0.0110
# DummyRegressor                   -0.0329 0.0430      0.0070
# LassoLars                        -0.0329 0.0430      0.0120
# HuberRegressor                   -0.0412 0.0432      0.0180
# RANSACRegressor                  -0.0504 0.0434      0.0279
# KernelRidge                      -0.0554 0.0435      0.0130
# LinearSVR                        -0.0568 0.0435      0.0160
# PassiveAggressiveRegressor       -0.0930 0.0443      0.0080
# SVR                              -0.1043 0.0445      0.0140
# MLPRegressor                     -2.9884 0.0846      0.0269
# GaussianProcessRegressor       -286.8362 0.7183      0.0116

# %%
#Here we are going to run the lazyRegressor sometimes with different states, because we have a small dataset so the R2
#statistic can vary signifcantly
i=0
models_sum=[[]]
for i in range(0,10):
    X_train1, X_test1, Y_train1, Y_test1 =train_test_split(X1,Y1,test_size=.3,random_state =i)
    regr=LazyRegressor(verbose=0,predictions=True)
    models_r,predictions_r=regr.fit(X_train1, X_test1, Y_train1, Y_test1)
    if i == 0:
        models_sum=models_r
    else:
        models_sum= models_sum + models_r
models_sum=models_sum/10
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:01<00:00, 41.29it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 45.31it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 46.12it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 44.28it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 46.76it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 45.28it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 46.64it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 46.90it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 44.69it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 42/42 [00:00<00:00, 46.62it/s]

# %%
models_sum.sort_values(by=['R-Squared'], ascending=False)
# Out:
#                                  R-Squared   RMSE  Time Taken
# Model
# RandomForestRegressor               0.3017 0.0257      0.1109
# GradientBoostingRegressor           0.2840 0.0259      0.0314
# BaggingRegressor                    0.2763 0.0263      0.0239
# DecisionTreeRegressor               0.2515 0.0246      0.0083
# XGBRegressor                        0.2423 0.0269      0.0494
# AdaBoostRegressor                   0.2266 0.0272      0.0326
# GammaRegressor                      0.0112 0.0293      0.0090
# NuSVR                              -0.0174 0.0295      0.0116
# LassoCV                            -0.0261 0.0294      0.0540
# ElasticNetCV                       -0.0261 0.0294      0.0521
# OrthogonalMatchingPursuit          -0.0326 0.0296      0.0081
# LinearSVR                          -0.0339 0.0299      0.0104
# OrthogonalMatchingPursuitCV        -0.0389 0.0295      0.0108
# HuberRegressor                     -0.0390 0.0299      0.0170
# TweedieRegressor                   -0.0411 0.0295      0.0086
# BayesianRidge                      -0.0414 0.0294      0.0093
# LassoLarsIC                        -0.0519 0.0295      0.0087
# LassoLarsCV                        -0.0553 0.0295      0.0140
# LarsCV                             -0.0553 0.0295      0.0137
# PoissonRegressor                   -0.0730 0.0298      0.0090
# Lasso                              -0.0770 0.0299      0.0081
# DummyRegressor                     -0.0770 0.0299      0.0076
# LassoLars                          -0.0770 0.0299      0.0082
# ElasticNet                         -0.0770 0.0299      0.0083
# LGBMRegressor                      -0.0935 0.0290      0.0429
# RANSACRegressor                    -0.0977 0.0303      0.0281
# SGDRegressor                       -0.1107 0.0299      0.0085
# HistGradientBoostingRegressor      -0.1420 0.0289      0.1111
# RidgeCV                            -0.1532 0.0299      0.0082
# Ridge                              -0.1909 0.0301      0.0084
# Lars                               -0.1960 0.0301      0.0083
# LinearRegression                   -0.1960 0.0301      0.0079
# TransformedTargetRegressor         -0.1960 0.0301      0.0088
# KernelRidge                        -0.3610 0.0314      0.0098
# ExtraTreesRegressor                -0.4622 0.0296      0.0851
# KNeighborsRegressor                -1.0582 0.0316      0.0081
# ExtraTreeRegressor                 -2.5498 0.0342      0.0097
# SVR                               -10.3327 0.0498      0.0085
# PassiveAggressiveRegressor        -17.3446 0.0498      0.0086
# MLPRegressor                      -75.5694 0.1203      0.0246
# GaussianProcessRegressor      -52,799.2329 2.4561      0.0110

# %% [markdown]
# #### We conclude that RandomForestRegressor seems to be the better process for our case.

# %% [markdown]
# ### Applying the selected model (RandomForestRegressor)

# %%
#now lets apply it to the whole dataframe that we have

from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

regr = RandomForestRegressor(random_state=0)
regr.fit(X1, Y1)
# Out:
# RandomForestRegressor(random_state=0)

# %%
dfC = pd.read_csv("NOTclient_country_info.csv", sep=';')

# %%
dfC.columns
# Out:
# Index(['location', 'continent', 'total_cases', 'total_cases_per_million',
#        'people_vaccinated', 'total_vaccinations_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'stringency_index', 'population',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
#        'gdp_per_capita', 'extreme_poverty', 'cardiovasc_death_rate',
#        'diabetes_prevalence', 'female_smokers', 'male_smokers',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'HDI', 'distance'],
#       dtype='object')

# %%
# lets exclude the missing data from the selected variables
dfC.dropna(subset=['population','gdp_per_capita','HDI'],inplace=True)

# %%
#Adding a new column with the predicted values for vaccinations per day per population
dfC['pred_vac_day_pop'] = regr.predict( dfC[['population','gdp_per_capita','HDI']] )

# %%
dfC[['location','pred_vac_day_pop']]
# Out:
#                location  pred_vac_day_pop
# 0           Afghanistan            0.0038
# 2                Angola            0.0012
# 3   Antigua and Barbuda            0.0189
# 4               Armenia            0.0007
# 6               Bahamas            0.0059
# ..                  ...               ...
# 88              Vanuatu            0.0140
# 90              Vietnam            0.0005
# 91                World            0.0038
# 92                Yemen            0.0037
# 93               Zambia            0.0005
#
# [85 rows x 2 columns]

# %% [markdown]
# ### Turning the variable values into Scores

# %%
#Receives a particular column and returns a score: a number between 1 and 10, depending on the bin that that number fits
def normalized_score(df_src, column_name, apply_log=True):
    i=0
    df=df_src.copy()
    if apply_log:
        df['log']=np.log(df[column_name]+0.00001)
    else:
        df['log']=df[column_name]
    
    df['log_score']=0
    for i in range(0,10):
        j=0
        for j,v in df['log'].items():
            if df.log[j] in df['log'].value_counts(bins=10, sort=False,normalize= True).index[i]:
                df['log_score'][j] = i+1 # score of 10 for the higher numbers
        
            if df.log[j]==df.log[j] and df['log_score'][j]==0: # special exception for the highest number, for it gets excluded from the interval
                df['log_score'][j]=10
    
    return df['log_score']

# %%
#now we create a dataframe to store the locations and the respective selected variables scores

dfD=pd.DataFrame(dfC['location'])
dfD['gdp_score']      =normalized_score(dfC, 'gdp_per_capita', apply_log=True)
dfD['HDI_score']      =normalized_score(dfC, 'HDI', apply_log=False) # HDI is already a index containing log
dfD['daily_vac_score']=normalized_score(dfC, 'pred_vac_day_pop', apply_log=True)
dfD['pop_score']      =normalized_score(dfC, 'population', apply_log=True)
dfD['distance']      =normalized_score(dfC, 'distance', apply_log=True)

# %%
dfD
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ba63ddbade9> in <module>
# ----> 1 dfD
#
# NameError: name 'dfD' is not defined
